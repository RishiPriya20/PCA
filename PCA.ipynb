# %% [markdown]
# **Task 1**

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %%
import pandas as pd
df= pd.read_csv("C:\\Users\\rishi\\OneDrive\\Desktop\\DS Assigments\\wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB
# None

# %%
print(df.head())
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
#Checking missing values
print(df.isnull().sum())
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
#Examing the distribution of features
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Histogram
df.hist(figsize=(12, 10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.show()

# %%
#Density plots
df.plot(kind='density', subplots=True, layout=(4, 4), figsize=(12, 10), sharex=False)
plt.show()

# %%
#Investigate correlations between features to understand relationships within the data
corr_matrix = df.corr()
#Displaying the correlation matrix
print(corr_matrix)
#Heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True,cmap='coolwarm', fmt='.2f')
plt.show()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %% [markdown]
# **Observation**

# %% [markdown]
# Loaded the data set from a CSV file
# The df.info() outputs shows the data types and non-null counts for each column. All columns have non-null values it indicates that there are no missing values in the dataset.
# 'df.head()' displays the first few rows of the dataset providing an overview of the data entries.
# Missing values: Used 'df.isnull().sum(); to check for missing values.
# after doing this there are no missing values in the dataset as all columns have zero missing values.
# Distribution of features:'Histrogram' of the features were plotted to visualize their distributions. This helps in understanding the spread and frequency of values for each feature.
# Most features seem to follow a normal distribution but some may have skewed distributions or outliers.
# Boxplots: Boxplots were created to show the distribution of values and detect any potential outliers.
# Several features have visible outliers which are points that lies far from the rest of the data.
# Density plots: Density plots for each feature were plotted to understand the ditribution more smoothly.
# Density plots provides a smooth estimate of the data distribution and helps in identifying patterns such as skewness or multi-modality in the features.
# Feature Correlations:We use correlation matrix to examine the relationships between features.
# A heatmap of the correlation matrix was plotted to visualize these relationships more clearly.
# The heatmap indicates which features are strongly positive or negatively correlated.

# %% [markdown]
# **Task 2**

# %% [markdown]
# **Dimensionality Reduction with PCA**

# %%
from sklearn.preprocessing import StandardScaler

target_column = 'Type'
#Seperateing features and target
X = df.drop(target_column, axis=1)
y = df[target_column]
#Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

from sklearn.preprocessing import LabelEncoder

# Encode the target column if needed
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
#Implementing PCA to reduce the dimensionality of the dataset
from sklearn.decomposition import PCA
#Applyinf PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
#Determinine the optimal number of principal components using techniques like scree plot or cumulative
#Scree plot
plt.plot(range(1, X_scaled.shape[1] + 1), pca.explained_variance_ratio_, 'o-')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.show()

# %%
#Cumulative exlained variance
cumulative_variance = pca.explained_variance_ratio_.cumsum()
plt.plot(range(1, X_scaled.shape[1] + 1), cumulative_variance, 'o-')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance')
plt.show()

# %%
#Transform the original dataset into the principal components
#Choosing the number of components based on the cumulative explained variance
n_components = 2
pca =PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# **Observation**

# %% [markdown]
# 1. Standardization: The features were standardized to have zero mean and unit variance.
# Used 'StandardScaler' from 'sklearn.preprocessing' to scale the data.
# This step checks that all features contribute equally to the PCA process, preventing any feature with a large scale from dominating the analysis
# Encoding Target Variable: The Target variable 'Type' was encoded into numerical values to prepare for PCA
# 2. Used 'LadelEncoder' from 'sklearn.preprocessing' to convert the target labels into numerical form.
# This conversion allows the target variable to be used in subsequent ML tasks.
# Applying PCA: PCA was applied to reduce the dimensionality of the dataset.
# Used 'PCA' from 'sklearn.decomposition' to transform the standardized features into principal components.
# 3. Determining the Optimal Number of Principal Components:
# Screen Plot: Plotted the explained variance ratio for each principal component.
# The screen plot helps to visualize how much variance each component explains. Typically there is a point where the explained variance starts to level off indicating a suitable number of components to retain.
# 4. Cumulative Explained Variance: Plotted the cumulative explained variance to show the total variance explained by the components.
# The cumulative variance plot helps a sufficient amount of the total variance.For suppose if the plot reaches around 80-90% cumulative variance with the first tew components those components are generally chosen.
# 5. Transforming the Data: It  Reduces the dataset to a smaller number of dimensions based on the PCA results.
# Chose 2 principal components based on the cumulative explained variance plot and re-applied PCA with 'n-components=2'
# The original data was transformed into two principal components simplifying the dataset while retaining most of the variance.

# %% [markdown]
# **Task 3**

# %% [markdown]
# **Clustering with original Data**

# %%
#Clustering with original Data
#Applying a clustering algorithm
from sklearn.cluster import KMeans
#Apply K-means clustering
kmeans = KMeans(n_clusters=3)
clusters = kmeans.fit_predict(X_scaled)
df['Cluster'] = clusters
#Visualize the clustering results using appropriate plots
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=clusters, palette='viridis')
plt.title('K-means Clustering on Original Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#Evalute the clustering performance using metrics such as silhouette score or Davies-Bouldin index
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Silhouette Score
silhouette_avg = silhouette_score(X_scaled, clusters)
print(f'Silhouette Score: {silhouette_avg}')

# Davies–Bouldin Index
dbi = davies_bouldin_score(X_scaled, clusters)
print(f'Davies–Bouldin Index: {dbi}')
# Out:
# Silhouette Score: 0.2848589191898987
# Davies–Bouldin Index: 1.389187977718165

# %% [markdown]
# **Observation**

# %% [markdown]
# 1. Clustering Algorithm:
# To apply K-means clustering to the original standardized dataset.
# Used the K-means algorithm with 'n-cluster =3' which means the algorithm tries to find 3 distinct clusters in the data.
# The K-means algorithm assigned each data point to one of the 3 clusters and these clusters were added as a new column named 'Cluster' in the dataset.
# 2. Visualization of Clustering Results:
# Scatter plot: Plotted a scatter plot of the first two features and colored the points based on their cluster assignments.
# The scatter plot shows how the data points are grouped into clusters. The colors represent different clusters, making it possible to visually assess how well the clusters are separated and if there is any overlap between them.
# 3. Clustering Performance Evaluation:
# Silhouette Score: It calculated the silhouette sore to measure how similar each point is to its cluster compared to other clusters. The score ranges from -1 to 1 where a higher score indicates better-defined clusters.
# The silhouette score was '0.2849' which suggests that the cluster have some separation but they are not very distinct.
# Davies-Bouldin Index:
# Calculated the Davies-Bouldin index to evaluated the average similarity ration of each cluster with its most similar cluster. A lower index indicates better clustering.
# The Davies-Bouldin index was '1.3892' indicating that the clusters might not be well-separated as the index value suggests some overlap between clusters.

# %% [markdown]
# **Task 4**

# %% [markdown]
# **Clustering with PCA Data**

# %%
#Clustering with PCA
#Applying the same clustering algorithm to PCA-transformed datset
# Apply K-means clustering to PCA-transformed data
kmeans_pca = KMeans(n_clusters=3)  # Choose the number of clusters
clusters_pca = kmeans_pca.fit_predict(X_pca)
df['Cluster_PCA'] = clusters_pca
#Visualize the clustering results obtained from PCA-transformed data
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=clusters_pca, palette='viridis')
plt.title('K-means Clustering on PCA-transformed Data')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#Comparing the clustering results from PCA-transformed data with those from the original dataset
# Compare clusters from original and PCA-transformed data
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=clusters, palette='viridis')
plt.title('Clustering on Original Data')

plt.subplot(1, 2, 2)
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=clusters_pca, palette='viridis')
plt.title('Clustering on PCA-transformed Data')

plt.show()

# %% [markdown]
# **Observation**

# %% [markdown]
# 1. Applying Clustering to PCA-Transformed Data: To apply the K-means clustering algorithm to the dataset after dimensionality reduction with PCA.
# 2. Used the K-means algorithm with 'n_clusters=3' on the PCA-Transformed data resulting in cluster assignments that were added to the dataset as a new column named 'Cluster_PCA'
# The data points were clustered into 3 groups based on the principal components.
# 2. Visualization of Clustering Results:
# The scatter plot shows that data points are grouped into clusters in the PCA-transformed space. This visualization helps in understanding the distribution and separation of clusters after dimensionality reduction.
# 3. Comparision of Clustering Results: Ploted two side-by-side scatter plots to compare clustering results
# Left plot: it shows clustering on the original standardized data.
# Right plot: it shows clustering on the PCA-transformed data.
# The original data plot shows the clusters are distributed based on the principal components.
# The PCA data plot shows how the clusters are distributed based on the principal components.
# By comparing these plots we can see how the clustering results differ between the original and PCA-transformed datasets.

# %%
**Task 5**

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have the clustering results for both datasets
# Clustering on original data
clusters_original = kmeans.predict(X_scaled)  # Or use your original clustering result
silhouette_original = silhouette_score(X_scaled, clusters_original)
dbi_original = davies_bouldin_score(X_scaled, clusters_original)

# Clustering on PCA-transformed data
clusters_pca = kmeans_pca.predict(X_pca)  # Or use your PCA clustering result
silhouette_pca = silhouette_score(X_pca, clusters_pca)
dbi_pca = davies_bouldin_score(X_pca, clusters_pca)

print(f"Original Data - Silhouette Score: {silhouette_original}, Davies-Bouldin Index: {dbi_original}")
print(f"PCA Data - Silhouette Score: {silhouette_pca}, Davies-Bouldin Index: {dbi_pca}")

# Visualize clustering results
plt.figure(figsize=(14, 6))

# Original Data
plt.subplot(1, 2, 1)
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=clusters_original, palette='viridis')
plt.title('Clustering on Original Data')

# PCA Data
plt.subplot(1, 2, 2)
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=clusters_pca, palette='viridis')
plt.title('Clustering on PCA-transformed Data')

plt.show()
# Out:
# Original Data - Silhouette Score: 0.2848589191898987, Davies-Bouldin Index: 1.389187977718165
# PCA Data - Silhouette Score: 0.5601697480957204, Davies-Bouldin Index: 0.5977226208167407

# %% [markdown]
# 1.	Apply the same clustering algorithm to the PCA-transformed dataset.

# %% [markdown]
# After performing clustering on both the original and PCA-transformed datasets the results indicate an improvement in clustering quality with PCA.

# %% [markdown]
# 2.	Discuss any similarities or differences observed in the clustering results.

# %% [markdown]
# The silhouette score increased from 0.285 to 0.561 which says that clusters are more distinct and better defined in the PCA space. The Davies-Bouldin index decreased from 1.389 to 0.597 it indicates that clusters are more compact and well separated after dimensionality reduction.
# By seeing in scatter plots with clusters in the PCA-transformed data appearing more distinct than the original data. Cluster mappings show a consistent correspondence between clusters in the original and PCA-transformed datasets even though some clusters have split into more refined groups in the PCA space.
# Lastly, PCA has enhanced clustering performance by improving the separation and compactness of clusters.

# %% [markdown]
# 3.	Reflect on the impact of dimensionality reduction on clustering performance.

# %% [markdown]
# Using PCA for clustering has both advantages and disadvantages. On the positive side, PCA improved clustering metrics making clusters more distinct and compact. This dimensionality reduction also makes the clustering process faster and less resourceful.

# %% [markdown]
# 4.	Analyze the trade-offs between using PCA and clustering directly on the original dataset.

# %% [markdown]
# The trade-off: PCA might have removed some features that could be important for clustering. This trade-off should be considered when deciding whether to use PCA most importantly if the clustering results are significantly better or worse with dimensionality reduction

# %% [markdown]
# **Tast 6**

# %% [markdown]
# 1.	Summarize the key findings and insights from the assignment.

# %% [markdown]
# By analyzing applying PCA to the dataset improved clustering performance.The silhouette score increased from 0.285 to 0.561 it indicates that better defined and more distinct clusters. Even with the Davies-Bouldin index decreased from 1,389 to 0.597, it says that the clusters became more compact and well separated after dimensionality reduction.
# Scatter plots confirmed these findings showing clearer separation between clusters in the PCA-transformed data compared to the original dataset.

# %% [markdown]
# 2. Discuss the Practical Implementations of Using PCA and Clustering

# %% [markdown]
# PCA offers practical advantages in data analysis particularly when dealing with high-dimensional datasets. By reducing dimensions PCA not only enhance clustering performance but also improves computational efficiency. This is important for tasks such as customer segmentation where clearer cluster separation can lead to better insights. The trade-off of potential information loss should be considered especially if the reduced features omit critical information. At last, while PCA can be highly effective its important to evaluate whether the benefits outweigh the potential loss of detail.

# %% [markdown]
# 3. Provide Recommendations for When to Use Each Technique

# %% [markdown]
# Based on analysis PCA should be considered when working with high-dimensional data where clustering performance needs enhancement and computational efficiency is a concern.PCA's ability to improve cluster separation and compactness makes it valuable for large datasets.However, if the dataset has a limited number of features or if retaining all features is critical PCA may not be necessary. In such cases clustering directly on the original data might be more appropriate to preserve all relevant information
